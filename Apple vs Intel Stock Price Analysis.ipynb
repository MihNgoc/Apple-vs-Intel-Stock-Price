# %%
# import library
import pandas as pd
import numpy as np

# import library for visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_price = pd.read_csv('./prices.csv')

# %%
stock_price.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %% [markdown]
# ## Apple

# %%
apple = stock_price[stock_price['symbol']=='AAPL']

# %%
apple
# Out:
#               date symbol        open       close         low        high  \
# 254     2010-01-04   AAPL  213.429998  214.009998  212.380001  214.499996
# 721     2010-01-05   AAPL  214.599998  214.379993  213.249994  215.589994
# 1189    2010-01-06   AAPL  214.379993  210.969995  210.750004  215.230000
# 1657    2010-01-07   AAPL  211.750000  210.580000  209.050005  212.000006
# 2125    2010-01-08   AAPL  210.299994  211.980005  209.060005  212.000006
# ...            ...    ...         ...         ...         ...         ...
# 848767  2016-12-23   AAPL  115.589996  116.519997  115.589996  116.519997
# 849267  2016-12-27   AAPL  116.519997  117.260002  116.489998  117.800003
# 849767  2016-12-28   AAPL  117.519997  116.760002  116.199997  118.019997
# 850267  2016-12-29   AAPL  116.449997  116.730003  116.400002  117.110001
# 850767  2016-12-30   AAPL  116.650002  115.820000  115.430000  117.199997
#
#              volume
# 254     123432400.0
# 721     150476200.0
# ...

# %%
plt.figure(figsize=(18, 8))
apple['date'] = pd.to_datetime(apple['date'])

plt.plot(apple['date'], apple['close'])
plt.plot(apple['date'], apple['open'])
plt.xticks(rotation=30)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Open and close prices of Apple stocks (2010-2017)')
plt.legend(['Open', 'Close'])
plt.show()
# Out:
# C:\Users\THAI2\AppData\Local\Temp\ipykernel_26196\1109828234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple['date'] = pd.to_datetime(apple['date'])

# %% [markdown]
# - We notice a sharply drop in the prices of shares in the middle of 2014 due to:
#     - The stock split
#     - Slower iPhone sales
#     - Concerns about Apple's future growth
#
# - After a fell, the stock price remain stable at that price until 2017.

# %%
plt.figure(figsize=(18, 8))
apple['date'] = pd.to_datetime(apple['date'])

plt.plot(apple['date'], apple['volume'])

plt.xticks(rotation=30)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Volume of stock traded (2010-2017)')
plt.show()
# Out:
# C:\Users\THAI2\AppData\Local\Temp\ipykernel_26196\3973258423.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple['date'] = pd.to_datetime(apple['date'])

# %% [markdown]
# - At the beginning of every year, there was a sharply increase in the volume of stock traded. Followed by a downward trend in the trading transaction throughout the whole year.
# - We can clearly see a reduction in the volume of stocks traded after 2014

# %% [markdown]
# ## Intel

# %%
intel = stock_price[stock_price['symbol']=='INTC']

# %%
intel.head()
# Out:
#             date symbol       open      close    low       high      volume
# 475   2010-01-04   INTC  20.790001  20.879999  20.73  21.030001  47800900.0
# 943   2010-01-05   INTC  20.940001  20.870001  20.60  20.990000  52357700.0
# 1411  2010-01-06   INTC  20.809999  20.799999  20.67  20.930000  40037400.0
# 1879  2010-01-07   INTC  20.730000  20.600000  20.34  20.760000  54041500.0
# 2347  2010-01-08   INTC  20.540001  20.830000  20.40  20.889999  48234700.0

# %%
plt.figure(figsize=(18, 8))
intel['date'] = pd.to_datetime(intel['date'])

plt.plot(intel['date'], intel['close'], 'b')
plt.plot(intel['date'], intel['open'], 'r')
plt.xticks(rotation=30)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Open and close prices of Intel stocks (2010-2017)')
plt.legend(['Open', 'Close'])
plt.show()
# Out:
# C:\Users\THAI2\AppData\Local\Temp\ipykernel_26196\2760219018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intel['date'] = pd.to_datetime(intel['date'])

# %% [markdown]
# - There was a steady upward trend for the stock price of Intel from 2013 till 2017
# - A clearly steep rise around May 2014 due to:
#     - Strong earnings
#     - Positive outlook
#     - M&A activity

# %%
plt.figure(figsize=(18, 8))
intel['date'] = pd.to_datetime(intel['date'])

plt.plot(intel['date'], intel['volume'])

plt.xticks(rotation=30)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Volume of stock traded (2010-2017)')
plt.show()
# Out:
# C:\Users\THAI2\AppData\Local\Temp\ipykernel_26196\3693423836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intel['date'] = pd.to_datetime(intel['date'])

# %% [markdown]
# - At the beginning of every year, there was a sharply increase in the volume of stock traded. Followed by a downward trend in the trading transaction throughout the whole year.
# - We can clearly see a reduction in the volume of stocks traded after 2014

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - In 2014, while there was a sharply drop in Apple's stock price, the stock price of Intel started a steady increase till 2017
# - From 2010 till the end of 2013, Intel and Apple both have a large voulme of strok traded
# - However, from 2014, there was a reduction in the volume of stock traded due to:
#     - Low interest rates make it less attractive to invest in stocks
#     - Rising stock prices (especially, Intel)
#     - Investor uncertainty
#     - Increased regulation of the financial industry can make it more difficult and costly for investors to trade
